# %%
f = open("/content/sample_data/READMEQ.md","w")
f.write("Content Deleted?..........")
f.close()

# %%
import os
os.remove("/content/sample_data/READMEQ.md")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-5eee09e185b6> in <module>()
#       1 import os
# ----> 2 os.remove("/content/sample_data/READMEQ.md")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/sample_data/READMEQ.md'

# %%
if os.path.exists("/content/sample_data/READMEQ.md"):
  os.remove("/content/sample_data/READMEQ.md")
else:
  print("The file does not exist")
# Out:
# The file does not exist

# %%
f = open("/content/sample_data/TestFolder/READMEQ.md","w")
f.write("Content Added?..........")
f.close()

# %%
import os
os.rmdir("/content/sample_data/TestFolder")

# %%
if os.path.exists("/content/sample_data/TestFolder/READMEQ.md"):
  os.remove("/content/sample_data/TestFolder/READMEQ.md")
else:
  print("The file does not exist")

# %%
with open("/content/sample_data/READMEQ.md","w") as f:
  f.write("Content Added?..........")
